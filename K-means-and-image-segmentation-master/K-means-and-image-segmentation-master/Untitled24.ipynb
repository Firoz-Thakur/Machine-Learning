# %%
from sklearn.datasets import make_blobs

# %%
X,y = make_blobs(n_samples = 1000, centers =6)
print(X.shape, y.shape)
# Out:
# (1000, 2) (1000,)

# %%
x.shape
# Out:
# (150, 2)

# %%
plt.figure(0)
plt.grid("On")
plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
from sklearn.cluster import KMeans
km=KMeans(n_clusters=5, init='random')

# %%
y_km=km.fit_predict(x)

# %%
plt.scatter(x[y_km==0,0], x[y_km==0,1], marker='o', c='red')
plt.scatter(x[y_km==1,0],x[y_km==1,1],c='green')
plt.scatter(x[y_km==2,0], x[y_km==2,1], c='orange')
plt.scatter(x[y_km==3,0], x[y_km==3,1], c='black')
plt.scatter(x[y_km==4,0], x[y_km==4,1], c='cyan')
plt.show()
