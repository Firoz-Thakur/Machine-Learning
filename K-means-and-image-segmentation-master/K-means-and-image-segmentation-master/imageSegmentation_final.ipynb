# %% [markdown]
# # Introduction :

# %% [raw]
# I am going to be using the K-Means Unsupervised Clustering Algorithm to segment the different types of the images.
# I am going to cluster pixels based on their spatial and color data only.

# %%
import cv2

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Load Image

# %%
im=cv2.imread('baba.jpg')
im=cv2.cvtColor(im,cv2.COLOR_BGR2RGB)
original_shape=im.shape
print(im.shape)
# Out:
# (1536, 3264, 3)

# %%
plt.imshow(im)
plt.show()

# %% [markdown]
# # Flatten each channel of the image to the linear Array

# %%
all_pixels=im.reshape((-1,3))
print(all_pixels.shape)
# Out:
# (5013504, 3)

# %%
original_shape
# Out:
# (1536, 3264, 3)

# %% [markdown]
# # KMeans

# %%
import sklearn.cluster

# %%
from sklearn.cluster import KMeans

# %%
dominant_colors=3
km=KMeans(n_clusters=dominant_colors)
km.fit(all_pixels)
# Out:
# KMeans(n_clusters=3)

# %%
centers=km.cluster_centers_

# %%
centers=np.array(centers,dtype='uint8')

# %%
print(centers)
# Out:
# [[ 64  69  49]
#  [250 250 242]
#  [125 122  91]]

# %% [markdown]
# # Plote what all colors  are these

# %%
i=1
plt.figure(0,figsize=(30,10))

colors=[]
for each_col in centers:
    plt.subplot(1,4,i)
 #   plt.axis("off")
    i+=1
    
    colors.append(each_col)
    
    #color swatch
    a=np.zeros((100,100,3),dtype='uint8')
    a[:,:,:]=each_col
    
    plt.imshow(a)
plt.show()

# %% [markdown]
# # Segment our orginal image

# %%
new_img=np.zeros((5013504,3),dtype='uint8')

print(new_img.shape)
# Out:
# (5013504, 3)

# %%
colors
# Out:
# [array([64, 69, 49], dtype=uint8),
#  array([250, 250, 242], dtype=uint8),
#  array([125, 122,  91], dtype=uint8)]

# %%
km.labels_
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
for ix in range(new_img.shape[0]):
     new_img[ix]=colors[km.labels_[ix]]

new_img=new_img.reshape((original_shape))
plt.imshow(new_img)
plt.show()

# %%
im=cv2.imread('Picture1.png')
im=cv2.cvtColor(im,cv2.COLOR_BGR2RGB)
original_shape=im.shape
print(im.shape)
# Out:
# (402, 531, 3)

# %%
plt.imshow(im)
plt.show()

# %%
all_pixels=im.reshape((-1,3))
print(all_pixels.shape)
# Out:
# (213462, 3)

# %%
original_shape
# Out:
# (402, 531, 3)

# %%
import sklearn.cluster

# %%
from sklearn.cluster import KMeans

# %%
dominant_colors=6
km=KMeans(n_clusters=dominant_colors)
km.fit(all_pixels)
# Out:
# KMeans(n_clusters=6)

# %%
centers=km.cluster_centers_

# %%
centers=np.array(centers,dtype='uint8')

# %%
print(centers)
# Out:
# [[ 81  91  32]
#  [109 142  60]
#  [220 210 138]
#  [ 40  52  13]
#  [132 105  59]
#  [155 165  90]]

# %%
i=1
plt.figure(0,figsize=(30,10))

colors=[]
for each_col in centers:
    plt.subplot(1,10,i)
 #   plt.axis("off")
    i+=1
    
    colors.append(each_col)
    
    #color swatch
    a=np.zeros((100,100,3),dtype='uint8')
    a[:,:,:]=each_col
    
    plt.imshow(a)
plt.show()

# %%
new_img=np.zeros((213462,3),dtype='uint8')

print(new_img.shape)
# Out:
# (213462, 3)

# %%
colors
# Out:
# [array([81, 91, 32], dtype=uint8),
#  array([109, 142,  60], dtype=uint8),
#  array([220, 210, 138], dtype=uint8),
#  array([40, 52, 13], dtype=uint8),
#  array([132, 105,  59], dtype=uint8),
#  array([155, 165,  90], dtype=uint8)]

# %%
km.labels_
# Out:
# array([3, 3, 3, ..., 0, 0, 0])

# %%
for ix in range(new_img.shape[0]):
     new_img[ix]=colors[km.labels_[ix]]

new_img=new_img.reshape((original_shape))
plt.imshow(new_img)
plt.show()
