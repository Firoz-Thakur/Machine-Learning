# %% [markdown]
# implelent the and fucntion using maclopids

# %%
import numpy as np
x1=[0,0,1,1]
x2=[0,1,0,1]
inhibit=0
target=[0,0,0,1]

# %%
threshold=2

# %% [markdown]
# ### and funciton ###

# %% [markdown]
# trheshold =2

# %%
if inhibit==0:
     for i in range(len(x1)):
            s=0
            print("input: ",x1[i],x2[i])
            s=x1[i]+x2[i]
            if s>=threshold:
                print("1")
            else:
                print("0")
else:
    print("neuron will not fire")
# Out:
# input:  0 0
# 0
# input:  0 1
# 0
# input:  1 0
# 0
# input:  1 1
# 1
